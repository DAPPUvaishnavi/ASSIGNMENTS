# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Q9_b.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
df.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
plt.boxplot(df.WT)
plt.xlabel("WT") 
plt.ylabel("Unnamed: 0")
plt.title("Boxplot of Q9_b.csv")
plt.show()

# %%
plt.boxplot(df.SP)
plt.xlabel("WT") 
plt.ylabel("Unnamed: 0")
plt.title("Boxplot of Q9_b.csv")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['WT'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(df['SP'])
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot(df.WT,df.SP,"rs")
plt.xlabel("WT")
plt.ylabel("SP")
plt.title("ScatterPlot")
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
plt.hist(df.WT)
plt.show()

# %%
plt.hist(df.SP)
plt.show()
